# %%
cd G:\MOPITT\Aeronet Gandhi College
# Out:
# G:\MOPITT\Aeronet Gandhi College

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'G:\MOPITT\Aeronet Gandhi College\20221020_20221026_Gandhi_College.lev15',
                  sep=',',
                  header=0,
                  index_col=False,
                   skiprows = 6,
                   parse_dates=[['Date(dd:mm:yyyy)', 'Time(hh:mm:ss)']]
                  )

# %%
data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'] =  pd.to_datetime(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],format="%d:%m:%Y %H:%M:%S")

# %%
data['AOD_1640nm'] = data['AOD_1640nm'].replace(-999.000000,np.nan)#AOD_551nm
data['AOD_1020nm'] = data['AOD_1020nm'].replace(-999.000000,np.nan)
data['AOD_870nm'] = data['AOD_870nm'].replace(-999.000000,np.nan)
data['AOD_675nm'] = data['AOD_675nm'].replace(-999.000000,np.nan)
data['AOD_709nm'] = data['AOD_709nm'].replace(-999.000000,np.nan)

# %%
fig=plt.figure(figsize=(13.5,4))#,constrained_layout=True)
ax = fig.subplots_adjust(bottom=0.1, top=0.9, left=0.1, right=0.8,wspace=0.2, hspace=0.02)

ax1 = plt.subplot(1,1, 1)        
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_1640nm'],label='AOD_1640nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_1020nm'],label='AOD_1020nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_870nm'],label='AOD_870nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_675nm'],label='AOD_675nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_500nm'],label='AOD_500nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_510nm'],label='AOD_510nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_440nm'],label='AOD_440nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_380nm'],label='AOD_380nm',lw=2)
ax1.plot(data['Date(dd:mm:yyyy)_Time(hh:mm:ss)'],data['AOD_340nm'],label='AOD_340nm',lw=2)

# ax1.set_ylim(0,16)
# ax1.set_xlim(0,40)
ax1.legend(loc=1)
ax1.grid(True)
plt.legend(prop={'family': 'Arial',"size":10,'weight':'bold'})
# ax1.set_xticks([-80,-70,-60,-50,-40,-30,-20,-10,0,10,20,30])
# ax1.set_yticks([0,2,4,6,8,10,12,14,16])
for tick in ax1.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('bold')
for tick in ax1.xaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('bold')
ax1.tick_params(axis='x', labelsize=15)
ax1.spines["left"].set_linewidth(2)
ax1.spines["right"].set_linewidth(2)
ax1.spines["top"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(axis='both', which='major', labelsize=15) 
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
    
fig.text(0.05, 0.5, 'AOD', va='center', rotation='vertical',fontsize=15,fontweight='bold',style='normal',        
         fontname='Arial')
fig.text(0.43, -0.01, 'Time', ha='center',fontsize=15,fontweight='bold',style='normal',
        fontname='Arial')
fig.text(0.46, 0.95, 'AERONET Version 3, Gandhi_College, Version 3: AOD Level 1.5', ha='center',fontsize=15,fontweight='bold',style='normal',
        fontname='Arial')
plt.savefig('AERONET.jpg',bbox_inches='tight',dpi=1080)
